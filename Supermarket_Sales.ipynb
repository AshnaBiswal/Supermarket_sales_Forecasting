# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file
df=pd.read_csv("supermarket_sales.csv")

# %%
#displaying the dataset
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#            Date   Time      Payment    cogs  gross margin percentage  \
# 0    01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1    03-08-2019  10:29         Cash   76.40                 4.761905
# 2    03-03-2019  13:23  Credit card  324.31                 4.761905
# 3     1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4    02-08-2019  10:37      Ewallet  604.17                 4.761905
# ..          ...    ...          ...     ...                      ...
# 995   1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996  03-02-2019  17:16      Ewallet  973.80                 4.761905
# 997  02-09-2019  13:22         Cash   31.84                 4.761905
# 998   2/22/2019  15:33         Cash   65.82                 4.761905
# 999   2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
#displaying the dimensions of dataset
df.shape
# Out:
# (1000, 17)

# %%
#displaying the summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
#checking the null values in each column and displaying their sum after sorting in descending order
df.isnull().sum().sort_values(ascending=False)
# Out:
# Invoice ID                 0
# Total                      0
# gross income               0
# gross margin percentage    0
# cogs                       0
# Payment                    0
# Time                       0
# Date                       0
# Tax 5%                     0
# Branch                     0
# Quantity                   0
# Unit price                 0
# Product line               0
# Gender                     0
# Customer type              0
# City                       0
# Rating                     0
# dtype: int64

# %%
#showing no.of data values against each unit price
plt.hist(df["Unit price"], bins=50)
plt.xlabel('Unit price')
plt.ylabel('Count')
plt.show()

# %%
#showing no.of data values against each quantity
plt.hist(df["Quantity"])
plt.xlabel('Quantity')
plt.ylabel('Count')
plt.show()

# %%
#showing no.of data values against tax amount
plt.hist(df["Tax 5%"])
plt.xlabel('Tax 5%')
plt.ylabel('Count')
plt.show()

# %%
#showing no.of data values against each total amount
plt.hist(df["Total"])
plt.xlabel('Total')
plt.ylabel('Count')
plt.show()

# %%
#showing no.of data values against cogs
plt.hist(df["cogs"])
plt.xlabel('cogs')
plt.ylabel('Count')
plt.show()

# %%
#showing no.of data values against rating
plt.hist(df["Rating"],bins=50)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
#displaying the transpose of statistical details
df.describe().T
# Out:
#                           count        mean           std        min  \
# Unit price               1000.0   55.672130  2.649463e+01  10.080000
# Quantity                 1000.0    5.510000  2.923431e+00   1.000000
# Tax 5%                   1000.0   15.379369  1.170883e+01   0.508500
# Total                    1000.0  322.966749  2.458853e+02  10.678500
# cogs                     1000.0  307.587380  2.341765e+02  10.170000
# gross margin percentage  1000.0    4.761905  6.131498e-14   4.761905
# gross income             1000.0   15.379369  1.170883e+01   0.508500
# Rating                   1000.0    6.972700  1.718580e+00   4.000000
#
#                                 25%         50%         75%          max
# Unit price                32.875000   55.230000   77.935000    99.960000
# Quantity                   3.000000    5.000000    8.000000    10.000000
# Tax 5%                     5.924875   12.088000   22.445250    49.650000
# Total                    124.422375  253.848000  471.350250  1042.650000
# cogs                     118.497500  241.760000  448.905000   993.000000
# gross margin percentage    4.761905    4.761905    4.761905     4.761905
# gross income               5.924875   12.088000   22.445250    49.650000
# Rating                     5.500000    7.000000    8.500000    10.000000

# %%
#displaying the distribution of single variables and relationships between two variables 
sns.pairplot(df)

# %%
#displaying heatmap of the correlation between variables
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#applying standard deviation method on cogs colunm and getting the index values 
index_cogs=df[df['cogs']>3*df['cogs'].std()+100].index
#removing the index from dataset to remove outliers 
df=df.drop(index_cogs,axis=0)

# %%
#displaying the distribution of single variables and relationships between two variables after removing outliers
sns.pairplot(df)

# %%
#displaying heatmap of the correlation between variables after removing outliers
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#changing the datatype of date column 
df['Date']=pd.DatetimeIndex(df['Date'])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 4         Sports and travel       86.31         7  30.2085  634.3785
# ..                      ...         ...       ...      ...       ...
# 994  Electronic accessories       60.95         1   3.0475   63.9975
# 995       Health and beauty       40.35         1   2.0175   42.3675
# 997      Food and beverages       31.84         1   1.5920   33.4320
# 998      Home and lifestyle       65.82         1   3.2910   69.1110
# 999     Fashion accessories       88.34         7  30.9190  649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0   2019-01-05  13:08      Ewallet  522.83                 4.761905
# 1   2019-03-08  10:29         Cash   76.40                 4.761905
# 2   2019-03-03  13:23  Credit card  324.31                 4.761905
# 3   2019-01-27  20:33      Ewallet  465.76                 4.761905
# 4   2019-02-08  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 994 2019-02-18  11:40      Ewallet   60.95                 4.761905
# 995 2019-01-29  13:46      Ewallet   40.35                 4.761905
# 997 2019-02-09  13:22         Cash   31.84                 4.761905
# 998 2019-02-22  15:33         Cash   65.82                 4.761905
# 999 2019-02-18  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 994        3.0475     5.9
# 995        2.0175     6.2
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [960 rows x 17 columns]

# %%
#converting date colunm back into proper column
df=df.sort_values(by='Date').reset_index(drop=True)

# %%
#plot between date and cogs column
plt.figure(figsize=(15,6))
plt.plot(df['Date'], df['cogs'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(df["cogs"],freq=15)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
# Out:
# <ipython-input-22-e596a67e7b97>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition = seasonal_decompose(df["cogs"],freq=15)

# %%
#displaying the trend,sesonality and noise pattern in dataset
plt.figure(figsize=(16,9))
plt.subplot(411)
plt.plot(df["cogs"], label='Original')
plt.legend(loc='upper right')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='upper right')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='upper right')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='upper right')
plt.tight_layout()

# %%
#performing dickey fuller test 
#according to dickey fuller test 
#    (i)if p value>0.05 then we will fail to reject null hypothesis which say data is non stationary
#   (ii)if p value<0.05 then we will reject null hypothesis and accept the alternate hypothesis which say data is stationary
from statsmodels.tsa.stattools import adfuller
dftest=adfuller(df['cogs'], autolag='AIC')
dfoutput=pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                 -30.386992
# p-value                          0.000000
# Lags Used                        0.000000
# Number of Observations Used    959.000000
# Critical Value (1%)             -3.437187
# Critical Value (5%)             -2.864559
# Critical Value (10%)            -2.568377
# dtype: float64

# %%
#finding the parameters of model against the lowest AIC value
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(df["cogs"], start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=2.78 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=14092.390, Time=0.12 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=13588.607, Time=1.00 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=1.56 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=13881.665, Time=0.18 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=13445.511, Time=2.67 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=11.12 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=2.95 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=13664.648, Time=0.75 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=13315.600, Time=4.00 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=13446.637, Time=1.32 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=12.70 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=4.10 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=13273.193, Time=4.38 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=13402.791, Time=1.65 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=inf, Time=15.22 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=4.79 sec
#  ARIMA(3,1,1)(2,1,0)[12]             : AIC=inf, Time=13.63 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=inf, Time=9.46 sec
#  ARIMA(3,1,0)(2,1,0)[12] intercept   : AIC=13275.193, Time=11.33 sec
#
# Best model:  ARIMA(3,1,0)(2,1,0)[12]
# Total fit time: 105.745 seconds
# 13273.19273879485

# %%
#importing Sarimax and passing the parameters
from statsmodels.tsa.statespace.sarimax import SARIMAX
m=SARIMAX(df['cogs'], order=(3,1,0),seasonal_order=(2,1,0,12))
res=m.fit()

# %%
#storing the predicted values in arima_predict
df['arima_predict']=res.fittedvalues

# %%
#plot between actual and predictes value
plt.figure(figsize=(20,12))
plt.plot(df['Date'].sort_values(),df['cogs'],label="actual")
plt.plot(df['Date'].sort_values(),df['arima_predict'],label="predicted")
plt.legend()

# %%
#forecasting for next 15 days
forecast=res.predict(start=len(df),end=len(df)+15)

# %%
forecast
# Out:
# 960    437.106178
# 961    380.020353
# 962    308.780036
# 963    486.125900
# 964    312.556826
# 965    344.068194
# 966    289.792083
# 967    327.894424
# 968    352.955330
# 969    360.019392
# 970    421.528391
# 971    320.990532
# 972    453.306659
# 973    453.202080
# 974    335.162808
# 975    452.043960
# Name: predicted_mean, dtype: float64

# %%
#combining forecast with cogs 
df['cogs'].append(forecast)
# Out:
# 0      435.660000
# 1      125.740000
# 2      175.320000
# 3      108.160000
# 4      380.720000
#           ...
# 971    320.990532
# 972    453.306659
# 973    453.202080
# 974    335.162808
# 975    452.043960
# Length: 976, dtype: float64

# %%
#plot between historical data and forecasted data
plt.figure(figsize=(20, 12))
plt.plot(df['cogs'],label="historical data")
plt.plot(forecast,label="forecasted data")
plt.legend()
